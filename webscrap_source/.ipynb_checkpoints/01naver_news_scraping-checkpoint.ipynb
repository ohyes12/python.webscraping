# %%
# !pip install selenium

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101'
req_header_dict = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36'
}
res = requests.get(url, headers=req_header_dict)
print(res.status_code, res.ok)
print(type(res))
print('응답해더', res.headers)
print('요청헤더', res.request.headers)
if res.ok:
    # 소스보기로 보여지는 text
    html = res.text
    soup = BeautifulSoup(html,'html.parser')
    print(soup)
# Out:
# 200 True
# <class 'requests.models.Response'>
# 응답해더 {'date': 'Thu, 27 Jan 2022 06:02:31 GMT', 'cache-control': 'no-cache', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'set-cookie': 'JSESSIONID=CF0AA25393FB6BDA90846D7B0EDD82CB; Path=/main; HttpOnly', 'content-language': 'ko-KR', 'vary': 'Accept-Encoding', 'content-encoding': 'gzip', 'transfer-encoding': 'chunked', 'content-type': 'text/html;charset=EUC-KR', 'referrer-policy': 'unsafe-url', 'server': 'nfront'}
# 요청헤더 {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# ...

# %%
if res.ok:
    #소스보기로 보여지는 text
    html = res.text
    soup = BeautifulSoup(html,'html.parser')
    # href 속성값에 read.naver 문자열이 포함된 a tag 선택하기
    atag_list = soup.select("a[href*='read.naver']")
    print(len(atag_list))
    for atag in atag_list:
        print(atag)
# Out:
# 238
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=215&amp;aid=0001011803">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/215/2022/01/27/1011803.jpg?type=nf132_90" width="132"/>
# </a>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=215&amp;aid=0001011803">지난해 수출입 물량·금액 역대 최고…교역조건은 악화</a>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=277&amp;aid=0005036825">지난해 12월 '수출·수입금액지수' 역대 최고</a>
# ...
